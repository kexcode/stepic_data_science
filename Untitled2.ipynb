# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

# %%
log_1 = pd.read_csv('/home/kex/Documents/log20190506_2.txt', delimiter='\t', header=0)

# %%
log_1= log_1.rename(columns={'Elapsed Time (sec)': 'time_sec'})

# %%
data_plt = log_1[['time_sec','Switch','Main magnet A','Main magnet B','Hall_sensor']]
data_2 = data_plt.drop(columns='time_sec')

# %%
sns.lineplot(data=data_plt, hue=data_2, palette="tab10", linewidth=2.5)
